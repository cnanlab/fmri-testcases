# %%
import nilearn as ni
from nilearn import image
from nilearn import plotting 
import polars as pl
import numpy as np

# %%
img_file = "/mnt/WarrenNAS/Data/processed_mri/SST/2025-12-17_07-55-33/sub-NDARINV0191C80U_ses-baselineYear1Arm1_task-sst_run-02LN.feat/filtered_func_data.nii.gz"

# %%
img_t = image.load_img(img_file)
arr_t = img_t.get_fdata()

# %%
arr_t.shape
# Out:
# (90, 90, 60, 437)

# %%
plotting.plot_glass_brain(image.index_img(img_t,100))

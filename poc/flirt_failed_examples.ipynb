# %%
import nilearn as nl
import nilearn.image as img
from nilearn import plotting

# %%
mni_path = "/mnt/storage/masks/MNI152_T1_2mm_brain.nii.gz"

# %%
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV003RTV85_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINV003RTV85_zfstat1_run-01_LN.nii.gz" # ~63k success roi
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV00UMK5VC_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINV00UMK5VC_zfstat1_run-01_LN.nii.gz" # ~100k 
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV00X2TBWJ_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINV00X2TBWJ_zfstat1_run-01_LN.nii.gz" # ~ 75k
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV00X2TBWJ_ses-baselineYear1Arm1_task-sst_run-02LN.feat/stats_roi/sub-NDARINV00X2TBWJ_zfstat1_run-02_LN.nii.gz" # ~ 85k
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVKC24Z5V5_ses-baselineYear1Arm1_task-sst_run-02LN.feat/stats_roi/sub-NDARINVKC24Z5V5_zfstat1_run-02_LN.nii.gz" # ~ 200k
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV8DZWHUBC_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINV8DZWHUBC_zfstat1_run-01_LN.nii.gz" # ~ 200k
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV7N96D4UW_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINV7N96D4UW_zfstat1_run-01_LN.nii.gz" # ~ 100k
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV0DC9BJZK_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINV0DC9BJZK_zfstat1_run-01_LN.nii.gz" # ~ 80k 
path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVWM4B6L05_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINVWM4B6L05_zfstat1_run-01_LN.nii.gz" # ~ 73k 
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV00CY2MDM_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats/zfstat1.nii.gz" 
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVGY65ZZBV_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats/zfstat1.nii.gz" # success roi
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVCU04NHFZ_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats/zfstat1.nii.gz" # success roi
#path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINV007W6H7B_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats/zfstat1.nii.gz"

# %%
path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVF3FYXH1G_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINVF3FYXH1G_zfstat1_run-01_LN_test.nii.gz"

# %% [markdown]
# /usr/local/fsl/bin/flirt -in /mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVF3FYXH1G_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINVF3FYXH1G_zfstat1_run-01_LN.nii.gz -ref /usr/local/fsl/data/standard/MNI152_T1_2mm_brain -out /mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVF3FYXH1G_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINVF3FYXH1G_zfstat1_run-01_LN_test.nii.gz -omat /mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVF3FYXH1G_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINVF3FYXH1G_zfstat1_run-01_LN_test.mat -bins 256 -cost normmi -searchrx -90 90 -searchry -90 90 -searchrz -90 90 -dof 9  -interp trilinear

# %%
path = "/mnt/WarrenNAS/Projects/processed_mri/sst/baseline/sub-NDARINVF3FYXH1G_ses-baselineYear1Arm1_task-sst_run-01LN.feat/stats_roi/sub-NDARINVF3FYXH1G_zfstat1_run-01_LN_test2.nii.gz"

# %%
plotting.plot_glass_brain(path)

# %%
display = plotting.plot_anat(path)
display.add_edges(mni_path)

# %%
display = plotting.plot_anat(path)
display.add_overlay(mni_path, cmap="hot")

# %%
html = plotting.view_img(path, bg_img=mni_path)
html.open_in_browser()
# Out:
# /home/axon/rkm160630/.conda/envs/ds1/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:840: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# (node:2923637) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)

# %%
/usr/local/fsl/bin/flirt -in highres -ref standard -out highres2standard -omat highres2standard.mat -cost corratio -dof 12 -searchrx -90 90 -searchry -90 90 -searchrz -90 90 -interp trilinear
# Out:
#   Cell In[8], line 1
#     usr/local/fsl/bin/flirt(-in, highres, -ref, standard, -out, highres2standard, -omat, highres2standard.mat, -cost, corratio, -dof, 12, -searchrx, -90, 90, -searchry, -90, 90, -searchrz, -90, 90, -interp, trilinear)
#                              ^
# SyntaxError: invalid syntax

# %%
/usr/local/fsl/bin/flirt -ref standard -in example_func -out example_func2standard -applyxfm -init example_func2standard.mat -interp trilinear

# %%
f'/usr/local/fsl/bin/flirt -in {test_rootdir}sub-{id}_ses-baselineYear1Arm1_task-sst_{run}.feat/stats/{img}.nii.gz -applyxfm -init {test_rootdir}sub-{id}_ses-baselineYear1Arm1_task-sst_{run_short}LN.feat/reg/example_func2standard.mat -out sub-{id}_{img}_{run_short}_LN -paddingsize 0.0 -interp trilinear -ref /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz'

# %%
f'/usr/local/fsl/bin/flirt -in {folder}/filtered_func_data.nii.gz -applyxfm -init {folder}/reg/example_func2standard.mat -out {folder}/filtered_func_data_ln.nii.gz -paddingsize 0.0 -interp trilinear -ref /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz'

# %%
import polars as pl
import altair as alt
alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
df_missing = pl.read_csv("../scores_thres-50000.txt", separator=" ")
df_missing.filter(pl.col.score > 80000).group_by(["subid", "run"]).agg(pl.col.score.mean())["subid"].unique()
# Out:
# shape: (1_019,)
# Series: 'subid' [str]
# [
# 	"NDARINV3E0WVH3G"
# 	"NDARINVTBHHD1UX"
# 	"NDARINV40JXNNYU"
# 	"NDARINVNGL4MJW6"
# 	"NDARINVM99BLZUE"
# 	…
# 	"NDARINV9R5J1TC2"
# 	"NDARINVD45YJJRT"
# 	"NDARINVCWN8ARJK"
# 	"NDARINV5WPTZ0W9"
# 	"NDARINV9W9BF541"
# ]

# %%
df_missing.group_by("subid").agg(pl.col.score.mean())["score"].to_pandas().plot.hist(xlabel="Score", ylabel="Participant Count", bins=50)
# Out:
# <Axes: xlabel='Score', ylabel='Participant Count'>

# %%
df_missing.group_by("subid").agg(pl.col.score.mean())["score"].plot.hist()
# Out:
# alt.Chart(...)

# %% [markdown]
# # Participants not being considered for any neuroimaging project

# %%
df_part_to_remove = df_missing.filter(pl.col.score > 100000)["subid"].unique()
df_part_to_remove#.to_frame().write_csv("../export/flirt_failed_part_id.csv")
# Out:
# shape: (259,)
# Series: 'subid' [str]
# [
# 	"NDARINV5TB3M4RT"
# 	"NDARINVL63XHP8H"
# 	"NDARINVWMPDRV7H"
# 	"NDARINVUWZLKLE0"
# 	"NDARINVV1F9DNZH"
# 	…
# 	"NDARINVHHJXG6Y1"
# 	"NDARINVLZHGWH8V"
# 	"NDARINVPE6W1Y3P"
# 	"NDARINV8U3ZUTV6"
# 	"NDARINV1BZ0TUT9"
# ]

# %%
df_roi = pl.read_csv("/mnt/storage/processed_roi/sst/sst_roi_14.csv")
df_roi
# Out:
# shape: (97_017_480, 8)
# ┌─────┬─────┬─────┬────────────┬─────┬─────────────────┬─────────┬────────┐
# │ x   ┆ y   ┆ z   ┆ activation ┆ roi ┆ subid           ┆ image   ┆ run    │
# │ --- ┆ --- ┆ --- ┆ ---        ┆ --- ┆ ---             ┆ ---     ┆ ---    │
# │ i64 ┆ i64 ┆ i64 ┆ f64        ┆ i64 ┆ str             ┆ str     ┆ str    │
# ╞═════╪═════╪═════╪════════════╪═════╪═════════════════╪═════════╪════════╡
# │ 46  ┆ 87  ┆ 29  ┆ -0.406948  ┆ 10  ┆ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 │
# │ 45  ┆ 85  ┆ 30  ┆ -0.116594  ┆ 10  ┆ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 │
# │ 46  ┆ 85  ┆ 30  ┆ -0.335568  ┆ 10  ┆ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 │
# │ 47  ┆ 85  ┆ 30  ┆ -0.5277    ┆ 10  ┆ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 │
# │ 44  ┆ 86  ┆ 30  ┆ -0.14198   ┆ 10  ┆ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 │
# │ …   ┆ …   ┆ …   ┆ …          ┆ …   ┆ …               ┆ …       ┆ …      │
# │ 57  ┆ 66  ┆ 67  ┆ -0.101983  ┆ 5   ┆ NDARINV9U32H2E4 ┆ zfstat6 ┆ run-02 │
# ...

# %%
df_roi["subid"].unique()
# Out:
# shape: (4_695,)
# Series: 'subid' [str]
# [
# 	"NDARINV6YVYFKU7"
# 	"NDARINVNT4P4M2F"
# 	"NDARINVCK8BV0JF"
# 	"NDARINVF5G7EUP1"
# 	"NDARINV8ZAB17TC"
# 	…
# 	"NDARINVMU02E5YC"
# 	"NDARINV8666P5JN"
# 	"NDARINVLZ0K08DY"
# 	"NDARINVYBJPP4VV"
# 	"NDARINVCTDL9XAC"
# ]

# %%
df_roi[["subid"]].unique().join(df_missing[["subid"]].unique(), on="subid", how="anti")
# Out:
# shape: (4, 1)
# ┌─────────────────┐
# │ subid           │
# │ ---             │
# │ str             │
# ╞═════════════════╡
# │ NDARINVDMWULU1K │
# │ NDARINVDN5NUU7W │
# │ NDARINVDL871HVM │
# │ NDARINVDMD17V8N │
# └─────────────────┘

# %%
df_missing_and_roi = df_missing.with_columns(pl.col.run.str.replace("LN", "")).join(
    df_roi,
    on=["subid", "image", "run"]
)
df_missing_and_roi
# Out:
# shape: (85_166_676, 11)
# ┌─────────────────┬─────────┬────────┬─────────┬───┬─────┬─────┬────────────┬─────┐
# │ subid           ┆ image   ┆ run    ┆ score   ┆ … ┆ y   ┆ z   ┆ activation ┆ roi │
# │ ---             ┆ ---     ┆ ---    ┆ ---     ┆   ┆ --- ┆ --- ┆ ---        ┆ --- │
# │ str             ┆ str     ┆ str    ┆ f64     ┆   ┆ i64 ┆ i64 ┆ f64        ┆ i64 │
# ╞═════════════════╪═════════╪════════╪═════════╪═══╪═════╪═════╪════════════╪═════╡
# │ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 ┆ 77425.0 ┆ … ┆ 87  ┆ 29  ┆ -0.406948  ┆ 10  │
# │ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 ┆ 77425.0 ┆ … ┆ 85  ┆ 30  ┆ -0.116594  ┆ 10  │
# │ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 ┆ 77425.0 ┆ … ┆ 85  ┆ 30  ┆ -0.335568  ┆ 10  │
# │ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 ┆ 77425.0 ┆ … ┆ 85  ┆ 30  ┆ -0.5277    ┆ 10  │
# │ NDARINV1V08GVK8 ┆ zfstat1 ┆ run-01 ┆ 77425.0 ┆ … ┆ 86  ┆ 30  ┆ -0.14198   ┆ 10  │
# │ …               ┆ …       ┆ …      ┆ …       ┆ … ┆ …   ┆ …   ┆ …          ┆ …   │
# ...

# %%
df_missing_and_roi.filter(pl.col.score > 200000)[["subid", "run", "score"]].unique().filter(subid="NDARINV8DZWHUBC")
# Out:
# shape: (2, 3)
# ┌─────────────────┬────────┬──────────┐
# │ subid           ┆ run    ┆ score    │
# │ ---             ┆ ---    ┆ ---      │
# │ str             ┆ str    ┆ f64      │
# ╞═════════════════╪════════╪══════════╡
# │ NDARINV8DZWHUBC ┆ run-01 ┆ 204063.0 │
# │ NDARINV8DZWHUBC ┆ run-02 ┆ 203710.0 │
# └─────────────────┴────────┴──────────┘

# %%
df_missing_and_roi.filter(pl.col.score > 100000, pl.col.score <= 200000)[["subid", "run", "score"]].unique().filter(subid="NDARINV7N96D4UW")
# Out:
# shape: (2, 3)
# ┌─────────────────┬────────┬──────────┐
# │ subid           ┆ run    ┆ score    │
# │ ---             ┆ ---    ┆ ---      │
# │ str             ┆ str    ┆ f64      │
# ╞═════════════════╪════════╪══════════╡
# │ NDARINV7N96D4UW ┆ run-02 ┆ 105256.0 │
# │ NDARINV7N96D4UW ┆ run-01 ┆ 105556.0 │
# └─────────────────┴────────┴──────────┘

# %%
df_missing_and_roi.filter(pl.col.score > 80000, pl.col.score < 100000)[["subid", "run", "score"]].unique().filter(subid="NDARINV0DC9BJZK")
# Out:
# shape: (2, 3)
# ┌─────────────────┬────────┬─────────┐
# │ subid           ┆ run    ┆ score   │
# │ ---             ┆ ---    ┆ ---     │
# │ str             ┆ str    ┆ f64     │
# ╞═════════════════╪════════╪═════════╡
# │ NDARINV0DC9BJZK ┆ run-01 ┆ 83033.0 │
# │ NDARINV0DC9BJZK ┆ run-02 ┆ 82907.0 │
# └─────────────────┴────────┴─────────┘

# %%
df_missing_and_roi.filter(pl.col.score <= 80000)[["subid", "run", "score"]].unique()
# Out:
# shape: (6_581, 3)
# ┌─────────────────┬────────┬─────────┐
# │ subid           ┆ run    ┆ score   │
# │ ---             ┆ ---    ┆ ---     │
# │ str             ┆ str    ┆ f64     │
# ╞═════════════════╪════════╪═════════╡
# │ NDARINVWM4B6L05 ┆ run-01 ┆ 74699.0 │
# │ NDARINVPTV6A941 ┆ run-02 ┆ 71609.0 │
# │ NDARINVM2EJE47J ┆ run-02 ┆ 66241.0 │
# │ NDARINV6N349E4J ┆ run-01 ┆ 62878.0 │
# │ NDARINV42J1GB3Y ┆ run-01 ┆ 71821.0 │
# │ …               ┆ …      ┆ …       │
# │ NDARINVDGVADKJA ┆ run-02 ┆ 76227.0 │
# │ NDARINV6EPGL57G ┆ run-02 ┆ 76702.0 │
# │ NDARINVC7BXUG5T ┆ run-02 ┆ 61943.0 │
# │ NDARINVB255ERX4 ┆ run-02 ┆ 66081.0 │
# │ NDARINVYNRJ8UU6 ┆ run-01 ┆ 75571.0 │
# └─────────────────┴────────┴─────────┘

# %%
df_sst_parti = pl.read_csv("/home/axon/rkm160630/software/sst_rsa_diffusion/sst_final_participant_ids.csv")
df_sst_parti
# Out:
# shape: (3_347, 1)
# ┌─────────────────┐
# │ part_id_final   │
# │ ---             │
# │ str             │
# ╞═════════════════╡
# │ NDARINVFM6CBFTY │
# │ NDARINVH52P6NHR │
# │ NDARINVXP05C9RL │
# │ NDARINVZN9E7J06 │
# │ NDARINVBG7FNXZB │
# │ …               │
# │ NDARINV897CW9GM │
# │ NDARINV5TEDV177 │
# │ NDARINV6NM33PV7 │
# │ NDARINV5BF7P17A │
# │ NDARINVCU8GZZV0 │
# └─────────────────┘

# %%
df_missing_and_roi.join(
    df_sst_parti,
    left_on="subid", right_on="part_id_final"
).filter((pl.col.score > 100000) | (pl.col.activation==0))["subid"].unique()
#
# Out:
# shape: (164,)
# Series: 'subid' [str]
# [
# 	"NDARINVCZ822Z4M"
# 	"NDARINVN160DMUM"
# 	"NDARINV1ACWERC3"
# 	"NDARINVWE1DE80Z"
# 	"NDARINVRR22WRZJ"
# 	…
# 	"NDARINVB8AV1T7K"
# 	"NDARINVMZZT8FFB"
# 	"NDARINVA140KMXY"
# 	"NDARINV7F1N85W0"
# 	"NDARINV1BUXN6LH"
# ]
